# %% [markdown]
# ### 10번. 앞에서 학습한 머신러닝 모델을 활용하여 시뮬레이션을 수행하고, 변수 중요도를 확인하고자 합니다. 아래 가이드를 참고하여 답안을 작성하세요.

# %% [markdown]
# ####
# 앞에서 만든 랜덤포레스트 모델로 시뮬레이션 수행 및 변수중요도를 확인하기 위해 가이드에 따라 코드를 작성하였습니다.
# - 학습한 랜덤포레스트 모델 rf를 활용하여 시뮬레이션 데이터(test_data)를 예측(predict)을 수행합니다.
# - 랜덤포레스트 모델 rf에 대한 변수중요도를 확인합니다.
#
# 가이드에 따라서 답안을 작성하세요.
# - 시뮬레이션 데이터(test_data)를 예측값을 '답안10' 변수에 저장하세요.(예. 답안10 = 0 혹은 1 혹은 2)
# - 랜덤포레스트 모델 rf의 변수중요도 중에서 가장 큰 변수중요도의 이름을 '답안10_1' 변수에 저장하세요.(예. 답안10_1 = '알맞은이름 입력하세요')

# %% [markdown]
# ##### 시뮬레이션 데이터와 변수 중요도를 활용하기 위해 아래 코드를 실행하세요.
